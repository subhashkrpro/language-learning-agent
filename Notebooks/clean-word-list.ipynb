# %%
import csv
import os
import subprocess
from string import punctuation
import pandas as pd

import spacy
import spacy_transformers
from wordfreq import zipf_frequency

# %%
def count_csv_elements_in_file(filepath):

    total_elements = 0

    with open(filepath, "r", encoding="utf-8") as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            total_elements += len(row)

    return total_elements

language = []
total_words = []

for path, subdirs, files in os.walk("../raw-word-list"):
    for name in files:
        filename = (os.path.join(path, name))
        language += [name.split(".")[0]]
        total_words += [count_csv_elements_in_file(filename)]

# %%
pd.DataFrame({
    "language": language,
    "total_words": total_words
})
# Out:
#       language  total_words
# 0      Catalan         3585
# 1      Chinese       406588
# 2     Croatian         3766
# 3       Danish      1800765
# 4        Dutch       173556
# 5      English       466434
# 6      Finnish        91672
# 7       French       336528
# 8       German      1707903
# 9        Greek        35279
# 10     Italian       661563
# 11    Japanese        44492
# 12      Korean       366504
# 13  Lithuanian        82627
# 14  Macedonian         3690
# 15   Norwegian       186966
# 16      Polish      4075605
# 17  Portuguese      1108873
# 18    Romanian       272616
# 19     Russian       171553
# 20   Slovenian       344442
# 21     Spanish       636598
# 22     Swedish       403791
# 23   Ukrainian       126308

# %%
spacy_models = {
    "Catalan": "ca_core_news_sm",
    "Chinese": "zh_core_web_sm",
    "Croatian": "hr_core_news_sm",
    "Danish": "da_core_news_sm",
    "Dutch": "nl_core_news_sm",
    "English": "en_core_web_sm",
    "Finnish": "fi_core_news_sm",
    "French": "fr_core_news_sm",
    "German": "de_core_news_sm",
    "Greek": "el_core_news_sm",
    "Italian": "it_core_news_sm",
    "Japanese": "ja_core_news_sm",
    "Korean": "ko_core_news_sm",
    "Lithuanian": "lt_core_news_sm",
    "Macedonian": "mk_core_news_sm",
    "Norwegian": "nb_core_news_sm",
    "Polish": "pl_core_news_sm",
    "Portuguese": "pt_core_news_sm",
    "Romanian": "ro_core_news_sm",
    "Russian": "ru_core_news_sm",
    "Slovenian": "sl_core_news_sm",
    "Spanish": "es_core_news_sm",
    "Swedish": "sv_core_news_sm",
    "Ukrainian": "uk_core_news_sm",
}

# %%
for model in spacy_models.values():
    result = subprocess.run(['uv','run','python', '-m', 'spacy', 'download', f'{model}'],
                       capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
# Out:
# ...
#      ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#      - -------------------------------------- 0.8/19.6 MB 2.6 MB/s eta 0:00:08
#      -- ------------------------------------- 1.3/19.6 MB 2.6 MB/s eta 0:00:07
#      ----- ---------------------------------- 2.6/19.6 MB 4.3 MB/s eta 0:00:04
#      ---------- ----------------------------- 5.0/19.6 MB 5.8 MB/s eta 0:00:03
#      ------------ --------------------------- 6.0/19.6 MB 6.4 MB/s eta 0:00:03
#      ------------------- -------------------- 9.4/19.6 MB 7.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 11.0/19.6 MB 7.5 MB/s eta 0:00:02
#      --------------------------- ------------ 13.4/19.6 MB 8.1 MB/s eta 0:00:01
#      -------------------------------- ------- 16.0/19.6 MB 8.5 MB/s eta 0:00:01
# ...

# %%
for language in spacy_models.keys():
    try:
        os.mkdir(f"../data/{language}")
        print(f"Directory {language} created")
    except FileExistsError:
        print(f"Directory {language} already exists")
# Out:
# Directory Catalan already exists
# Directory Chinese already exists
# Directory Croatian already exists
# Directory Danish already exists
# Directory Dutch already exists
# Directory English already exists
# Directory Finnish already exists
# Directory French already exists
# Directory German already exists
# Directory Greek already exists
# Directory Italian already exists
# Directory Japanese already exists
# Directory Korean already exists
# Directory Lithuanian already exists
# Directory Macedonian already exists
# Directory Norwegian already exists
# Directory Polish already exists
# Directory Portuguese already exists
# Directory Romanian already exists
# Directory Russian already exists
# Directory Slovenian already exists
# Directory Spanish already exists
# Directory Swedish already exists
# Directory Ukrainian already exists

# %%
def load_and_clean_word_list(language_name: str) -> pd.DataFrame:
    with open(f"../raw-word-list/{language_name}/{language_name}.txt", "r", encoding="utf-8") as file:
        word_list = file.read().split(",")

    word_df = pd.DataFrame({
        "word": word_list
    })

    word_df["word"] = word_df["word"].str.strip(punctuation)

    return word_df

# %%
load_and_clean_word_list("English")
# Out:
#               word
# 0         aardvark
# 1        aardvarks
# 2         aardwolf
# 3       aardwolves
# 4            Aaren
# ...            ...
# 466429      Zwolle
# 466430    Zworykin
# 466431          ZZ
# 466432         zZt
# 466433       ZZZ\n
#
# [466434 rows x 1 columns]

# %%
nlp = spacy.load(spacy_models["English"], disable=["parser", "ner", "textcat"])

# %%
def add_lemma(df: pd.DataFrame,
              nlp,
              batch_size: int = 1000) -> pd.DataFrame:
    docs = nlp.pipe(df["word"].tolist(), batch_size=batch_size)
    lemmas = []
    for doc in docs:
        # Handle empty documents or documents with no tokens
        if len(doc) > 0:
            lemmas.append(doc[0].lemma_)
        else:
            # Use original word if no tokens were produced
            lemmas.append(doc.text)
    df["lemma"] = pd.DataFrame(lemmas, index=df.index)
    return df

# %%
add_lemma(
    load_and_clean_word_list("English")[:100], nlp
)
# Out:
#           word     lemma
# 0     aardvark  aardvark
# 1    aardvarks  aardvark
# 2     aardwolf  aardwolf
# 3   aardwolves  aardwolf
# 4        Aaren     Aaren
# ..         ...       ...
# 95       Abama     Abama
# 96       abamp     abamp
# 97    abampere  abampere
# 98   abamperes  abampere
# 99      abamps    abamps
#
# [100 rows x 2 columns]

# %%
def add_word_frequencies(df: pd.DataFrame,
                         language_name: str) -> pd.DataFrame:
    language_group = spacy_models[language_name].split("_")[0]
    df["zipf_freq_lemma"] = [zipf_frequency(w, language_group) for w in df["lemma"]]
    return df

# %%
add_word_frequencies(
    add_lemma(
        load_and_clean_word_list("English")[:100], nlp
), "English")
# Out:
#           word     lemma  zipf_freq_lemma
# 0     aardvark  aardvark             2.39
# 1    aardvarks  aardvark             2.39
# 2     aardwolf  aardwolf             1.11
# 3   aardwolves  aardwolf             1.11
# 4        Aaren     Aaren             0.00
# ..         ...       ...              ...
# 95       Abama     Abama             0.00
# 96       abamp     abamp             0.00
# 97    abampere  abampere             0.00
# 98   abamperes  abampere             0.00
# 99      abamps    abamps             0.00
#
# [100 rows x 3 columns]

# %%
def clean_up_and_export(df: pd.DataFrame, language_name: str) -> None:
    df = (
        df.loc[df.groupby("lemma", sort=False)["zipf_freq_lemma"].idxmax()]
        .reset_index(drop=True)
    )

    df = df[(df["zipf_freq_lemma"] > 0)]

    df.loc[:, "word_difficulty"] = pd.cut(
        df["zipf_freq_lemma"],
        bins = [-float("inf"), 2.0, 4.0, float("inf")],
        labels = ["advanced", "intermediate", "beginner"],
        include_lowest = True,
        right = True
    )

    df = df.drop(columns=["word", "zipf_freq_lemma"])
    df = df.rename(columns = {
        "lemma": "word"
    })

    df.to_json(f"../data/{language_name}/word-list-cleaned.json", orient="index", force_ascii=False)

# %%
clean_up_and_export(
    add_word_frequencies(
        add_lemma(
            load_and_clean_word_list("English")[:100], nlp),
        "English"),
    "English")

# %%
def create_clean_word_list(language_name: str) -> None:
    nlp = spacy.load(spacy_models[language_name], disable=["parser", "ner", "textcat"])

    print("Load in dataset")
    lang_df = load_and_clean_word_list(language_name)

    print("Lemmatise words")
    lang_df = add_lemma(lang_df, nlp)

    print("Add the word frequencies")
    lang_df = add_word_frequencies(lang_df, language_name)

    print("Do the final clean ups and export to file")
    clean_up_and_export(lang_df, language_name)

    return None

# %%
# create_clean_word_list("Spanish")

# %%
print("Processing all available languages...\n")

processed = 0
skipped = 0
errors = 0
error_details = []

for language in spacy_models.keys():
    output_file = f"../data/{language}/word-list-cleaned.json"
    
    # Check if output file already exists
    if os.path.exists(output_file):
        print(f"⊘ Skipping {language} - word list already exists")
        skipped += 1
        continue
    
    print(f"{'='*50}")
    print(f"Processing: {language}")
    print(f"{'='*50}")
    try:
        create_clean_word_list(language)
        print(f"✓ Successfully processed {language}\n")
        processed += 1
    except Exception as e:
        error_msg = str(e)
        print(f"✗ Error processing {language}: {error_msg}\n")
        errors += 1
        error_details.append({"language": language, "error": error_msg})

print(f"\n{'='*50}")
print(f"Summary:")
print(f"  Processed: {processed}")
print(f"  Skipped: {skipped}")
print(f"  Errors: {errors}")
print(f"{'='*50}")

if error_details:
    print("\nFailed Languages:")
    for detail in error_details:
        print(f"  - {detail['language']}: {detail['error']}")
# Out:
# Processing all available languages...
#
# ...
# Processing: Catalan
# ...
# Load in dataset
# Lemmatise words
# Add the word frequencies
# Do the final clean ups and export to file
# ✓ Successfully processed Catalan
#
# ...
# Processing: Chinese
# ...
# Load in dataset
# Lemmatise words
# ✗ Error processing Chinese: [E040] Attempt to access token at 0, max length 0.
#
# ...
# Processing: Croatian
# ...
# Load in dataset
# Lemmatise words
# You asked for word frequencies in language 'hr'. Using the nearest match, which is 'sh'.
# Add the word frequencies
# Do the final clean ups and export to file
# ✓ Successfully processed Croatian
#
# ...
# Processing: Danish
# ...
# Load in dataset
# Lemmatise words
# Add the word frequencies
# Do the final clean ups and export to file
# ✓ Successfully processed Danish
#
# ...
# Processing: Dutch
# ...
# Load in dataset
# Lemmatise words
# ✗ Error processing Dutch: [E040] Attempt to access token at 0, max length 0.
#
# ⊘ Skipping English - word list already exists
# ...
# Processing: Finnish
# ...
# Load in dataset
# ...

# %% [markdown]
# ## Fix for Japanese and Korean Processing
#
# If you see errors for Japanese or Korean about missing MeCab, install it with:
#
# ```bash
# # Install MeCab (required for Japanese and Korean)
# uv pip install mecab-python3
#
# # On Windows, you may also need to install the MeCab binary:
# # Download from: https://github.com/ikegami-yukino/mecab/releases
# ```
#
# After installation, re-run the batch processing cell to process these languages.

# %%
# Reprocess only failed languages
failed_languages = ["Chinese", "Japanese", "Korean"]

print("Reprocessing failed languages...\n")
for language in failed_languages:
    output_file = f"../data/{language}/word-list-cleaned.json"
    
    if os.path.exists(output_file):
        print(f"⊘ {language} - already processed successfully")
        continue
        
    print(f"Processing: {language}")
    try:
        create_clean_word_list(language)
        print(f"✓ {language} processed successfully\n")
    except Exception as e:
        print(f"✗ {language} failed: {str(e)}\n")
# Out:
# Reprocessing failed languages...
#
# Processing: Chinese
# Load in dataset
# Lemmatise words
# Add the word frequencies
# d:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages\jieba\__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# d:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages\jieba\__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# d:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages\jieba\finalseg\__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# Do the final clean ups and export to file
# ✓ Chinese processed successfully
#
# Processing: Japanese
# Load in dataset
# Lemmatise words
# Add the word frequencies
# Do the final clean ups and export to file
# ✓ Japanese processed successfully
#
# Processing: Korean
# ...

# %% [markdown]
# ## Re-export with Proper Unicode
#
# The files were saved with ASCII escape sequences. Re-export them with actual Unicode characters for readability.

# %%
import json

print("Re-exporting JSON files with proper Unicode encoding...\n")

re_exported = 0

for language in spacy_models.keys():
    json_file = f"../data/{language}/word-list-cleaned.json"
    
    if not os.path.exists(json_file):
        continue
    
    # Read the existing JSON file
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    # Re-write with force_ascii=False to preserve Unicode characters
    with open(json_file, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    
    print(f"✓ Re-exported {language}")
    re_exported += 1

print(f"\nTotal files re-exported: {re_exported}")
# Out:
# Re-exporting JSON files with proper Unicode encoding...
#
# ✓ Re-exported Catalan
# ✓ Re-exported Chinese
# ✓ Re-exported Croatian
# ✓ Re-exported Danish
# ✓ Re-exported Dutch
# ✓ Re-exported English
# ✓ Re-exported Finnish
# ✓ Re-exported French
# ✓ Re-exported German
# ✓ Re-exported Greek
# ✓ Re-exported Italian
# ✓ Re-exported Japanese
# ✓ Re-exported Korean
# ✓ Re-exported Lithuanian
# ✓ Re-exported Macedonian
# ✓ Re-exported Norwegian
# ✓ Re-exported Polish
# ✓ Re-exported Portuguese
# ✓ Re-exported Romanian
# ✓ Re-exported Russian
# ✓ Re-exported Slovenian
# ✓ Re-exported Spanish
# ✓ Re-exported Swedish
# ✓ Re-exported Ukrainian
#
# Total files re-exported: 24

# %%
import json

language_raw = []
total_words_raw = []

for path, subdirs, files in os.walk("../raw-word-list"):
    for name in files:
        filename = (os.path.join(path, name))
        language_raw += [name.split(".")[0]]
        total_words_raw += [count_csv_elements_in_file(filename)]

raw_data = pd.DataFrame({
    "language": language_raw,
    "type": ["Raw"] * len(language_raw),
    "total_words_raw": total_words_raw,
})

# %%
language_clean = []
total_words_clean = []

for path, subdirs, files in os.walk("../data"):
    for name in files:
        filename = (os.path.join(path, name))
        language_clean += [path.split("/")[1]]
        with open(filename, "r", encoding="utf-8") as f:
            data = json.load(f)
            total_words_clean += [len(data.keys())]

clean_data = pd.DataFrame({
    "language": language_clean,
    "type": ["Clean"] * len(language_clean),
    "total_words_raw": total_words_clean,
})

pd.concat([raw_data, clean_data])
# Out:
#            language   type  total_words_raw
# 0           Catalan    Raw             3585
# 1           Chinese    Raw           406588
# 2          Croatian    Raw             3766
# 3            Danish    Raw          1800765
# 4             Dutch    Raw           173556
# 5           English    Raw           466434
# 6           Finnish    Raw            91672
# 7            French    Raw           336528
# 8            German    Raw          1707903
# 9             Greek    Raw            35279
# 10          Italian    Raw           661563
# 11         Japanese    Raw            44492
# 12           Korean    Raw           366504
# 13       Lithuanian    Raw            82627
# 14       Macedonian    Raw             3690
# 15        Norwegian    Raw           186966
# 16           Polish    Raw          4075605
# 17       Portuguese    Raw          1108873
# 18         Romanian    Raw           272616
# 19          Russian    Raw           171553
# ...
