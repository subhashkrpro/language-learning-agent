# %%
import csv
import os
import subprocess
from string import punctuation
import pandas as pd

import spacy
import spacy_transformers
from wordfreq import zipf_frequency

# %%
def count_csv_elements_in_file(filepath):

    total_elements = 0

    with open(filepath, "r", encoding="utf-8") as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            total_elements += len(row)

    return total_elements

language = []
total_words = []

for path, subdirs, files in os.walk("../raw-word-list"):
    for name in files:
        filename = (os.path.join(path, name))
        language += [name.split(".")[0]]
        total_words += [count_csv_elements_in_file(filename)]

# %%
pd.DataFrame({
    "language": language,
    "total_words": total_words
})
# Out:
#       language  total_words
# 0      Catalan         3585
# 1      Chinese       406588
# 2     Croatian         3766
# 3       Danish      1800765
# 4        Dutch       173556
# 5      English       466434
# 6      Finnish        91672
# 7       French       336528
# 8       German      1707903
# 9        Greek        35279
# 10     Italian       661563
# 11    Japanese        44492
# 12      Korean       366504
# 13  Lithuanian        82627
# 14  Macedonian         3690
# 15   Norwegian       186966
# 16      Polish      4075605
# 17  Portuguese      1108873
# 18    Romanian       272616
# 19     Russian       171553
# 20      Slovak      1794373
# 21   Slovenian       344442
# 22     Spanish       636598
# 23     Swedish       403791
# 24   Ukrainian       126308

# %%
spacy_models = {
    "Catalan": "ca_core_news_sm",
    "Chinese": "zh_core_web_sm",
    "Croatian": "hr_core_news_sm",
    "Danish": "da_core_news_sm",
    "Dutch": "nl_core_news_sm",
    "English": "en_core_web_sm",
    "Finnish": "fi_core_news_sm",
    "French": "fr_core_news_sm",
    "German": "de_core_news_sm",
    "Greek": "el_core_news_sm",
    "Italian": "it_core_news_sm",
    "Japanese": "ja_core_news_sm",
    "Korean": "ko_core_news_sm",
    "Lithuanian": "lt_core_news_sm",
    "Macedonian": "mk_core_news_sm",
    "Norwegian": "nb_core_news_sm",
    "Polish": "pl_core_news_sm",
    "Portuguese": "pt_core_news_sm",
    "Romanian": "ro_core_news_sm",
    "Russian": "ru_core_news_sm",
    "Slovenian": "sl_core_news_sm",
    "Spanish": "es_core_news_sm",
    "Swedish": "sv_core_news_sm",
    "Ukrainian": "uk_core_news_sm",
}

# %%
for model in spacy_models.values():
    result = subprocess.run(['uv','run','python', '-m', 'spacy', 'download', f'{model}'],
                       capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
# Out:
# Collecting ca-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ca_core_news_sm-3.8.0/ca_core_news_sm-3.8.0-py3-none-any.whl (19.6 MB)
#      ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.6 MB ? eta -:--:--
#      - -------------------------------------- 0.5/19.6 MB 1.0 MB/s eta 0:00:19
#      - ------------------------------------- 0.8/19.6 MB 987.0 kB/s eta 0:00:20
#      - ------------------------------------- 0.8/19.6 MB 987.0 kB/s eta 0:00:20
#      -- ------------------------------------ 1.0/19.6 MB 849.0 kB/s eta 0:00:22
#      -- ------------------------------------ 1.3/19.6 MB 933.8 kB/s eta 0:00:20
#      -- ------------------------------------ 1.3/19.6 MB 933.8 kB/s eta 0:00:20
MB 1.7 MB/s eta 0:00:01
#      -------------------------------------- - 18.6/19.6 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  19.4/19.6 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------- 19.6/19.6 MB 1.8 MB/s  0:00:11
# Installing collected packages: ca-core-news-sm
# Successfully installed ca-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('ca_core_news_sm')
#
#
# Collecting zh-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.8.0/zh_core_web_sm-3.8.0-py3-none-any.whl (48.5 MB)
#      ---------------------------------------- 0.0/48.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/48.5 MB ? eta -:--:--
#       --------------------------------------- 1.0/48.5 MB 3.3 MB/s eta 0:00:15
#      - -------------------------------------- 1.3/48.5 MB 3.0 MB/s eta 0:00:16
#      - -------------------------------------- 1.8/48.5 MB 2.7 MB/s eta 0:00:18
#      -- ------------------------------------- 2.6/48.5 MB 2.7 MB/s eta 0:00:18
#      -- ------------------------------------- 2.9/48.5 MB 2.8 MB/s eta 0:00:17
#      --- ------------------------------------ 3.7/48.5 MB 2.7 MB/s eta 0:00:17
#      --- ------------------------------------ 4.2/48.5 MB 2.7 MB/s eta 0:00:17
#      ---- ----------------------------------- 5.0/48.5 MB 2.7 MB/s eta 0:00:16
#      ---- ----------------------------------- 5.2/48.5 MB 2.6 MB/s eta 0:00:17
#      ---- ----------------------------------- 5.8/48.5 MB 2.7 MB/s eta 0:00:17
#      ----- ---------------------------------- 6.3/48.5 MB 2.7 MB/s eta 0:00:16
#      ----- ---------------------------------- 6.8/48.5 MB 2.6 MB/s eta 0:00:17
#      ------ --------------------------------- 7.9/48.5 MB 2.7 MB/s eta 0:00:16
#      ------ --------------------------------- 8.4/48.5 MB 2.7 MB/s eta 0:00:15
#      ------- -------------------------------- 9.2/48.5 MB 2.8 MB/s eta 0:00:15
#      ------- -------------------------------- 9.7/48.5 MB 2.7 MB/s eta 0:00:15
#      -------- ------------------------------- 10.5/48.5 MB 2.8 MB/s eta 0:00:14
#      --------- ------------------------------ 11.3/48.5 MB 2.8 MB/s eta 0:00:14
#      ---------- ----------------------------- 12.3/48.5 MB 2.9 MB/s eta 0:00:13
#      ----------- ---------------------------- 13.4/48.5 MB 3.0 MB/s eta 0:00:12
#      ----------- ---------------------------- 14.4/48.5 MB 3.1 MB/s eta 0:00:11
#      ------------ --------------------------- 15.5/48.5 MB 3.2 MB/s eta 0:00:11
#      ------------- -------------------------- 16.5/48.5 MB 3.3 MB/s eta 0:00:10
#      -------------- ------------------------- 17.0/48.5 MB 3.2 MB/s eta 0:00:10
#      -------------- ------------------------- 17.8/48.5 MB 3.3 MB/s eta 0:00:10
#      --------------- ------------------------ 18.9/48.5 MB 3.3 MB/s eta 0:00:09
#      ---------------- ----------------------- 19.7/48.5 MB 3.3 MB/s eta 0:00:09
#      ---------------- ----------------------- 19.9/48.5 MB 3.3 MB/s eta 0:00:09
#      ------------------------------- -------- 38.8/48.5 MB 2.7 MB/s eta 0:00:04
#      -------------------------------- ------- 39.1/48.5 MB 2.7 MB/s eta 0:00:04
#      -------------------------------- ------- 39.6/48.5 MB 2.7 MB/s eta 0:00:04
#      -------------------------------- ------- 39.8/48.5 MB 2.7 MB/s eta 0:00:04
#      --------------------------------- ------ 40.4/48.5 MB 2.7 MB/s eta 0:00:04
#      --------------------------------- ------ 40.6/48.5 MB 2.7 MB/s eta 0:00:03
#      --------------------------------- ------ 40.9/48.5 MB 2.7 MB/s eta 0:00:03
#      --------------------------------- ------ 41.2/48.5 MB 2.6 MB/s eta 0:00:03
#      ---------------------------------- ----- 41.7/48.5 MB 2.6 MB/s eta 0:00:03
#      ---------------------------------- ----- 41.9/48.5 MB 2.6 MB/s eta 0:00:03
#      ----------------------------------- ---- 42.5/48.5 MB 2.6 MB/s eta 0:00:03
#      ----------------------------------- ---- 42.7/48.5 MB 2.6 MB/s eta 0:00:03
#      ----------------------------------- ---- 43.0/48.5 MB 2.6 MB/s eta 0:00:03
#      ----------------------------------- ---- 43.3/48.5 MB 2.6 MB/s eta 0:00:03
#      ------------------------------------ --- 43.8/48.5 MB 2.5 MB/s eta 0:00:02
#      ------------------------------------ --- 44.0/48.5 MB 2.5 MB/s eta 0:00:02
#      ------------------------------------ --- 44.6/48.5 MB 2.5 MB/s eta 0:00:02
#      ------------------------------------- -- 45.1/48.5 MB 2.5 MB/s eta 0:00:02
#      ------------------------------------- -- 45.4/48.5 MB 2.5 MB/s eta 0:00:02
#      -------------------------------------- - 46.1/48.5 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------- - 46.7/48.5 MB 2.5 MB/s eta 0:00:01
#      -------------------------------------- - 47.2/48.5 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------  47.7/48.5 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------  48.0/48.5 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------  48.5/48.5 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------- 48.5/48.5 MB 2.5 MB/s  0:00:19
# Collecting spacy-pkuseg<2.0.0,>=1.0.0 (from zh-core-web-sm==3.8.0)
#   Downloading spacy_pkuseg-1.0.1-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.19.0 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from spacy-pkuseg<2.0.0,>=1.0.0->zh-core-web-sm==3.8.0) (2.4.2)
# Requirement already satisfied: srsly<3.0.0,>=2.3.0 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from spacy-pkuseg<2.0.0,>=1.0.0->zh-core-web-sm==3.8.0) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from srsly<3.0.0,>=2.3.0->spacy-pkuseg<2.0.0,>=1.0.0->zh-core-web-sm==3.8.0) (2.0.10)
# Downloading spacy_pkuseg-1.0.1-cp313-cp313-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.4 MB 2.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.4 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.8/2.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 1.4 MB/s  0:00:01
# Installing collected packages: spacy-pkuseg, zh-core-web-sm
#
#    -------------------- ------------------- 1/2 [zh-core-web-sm]
#    -------------------- ------------------- 1/2 [zh-core-web-sm]
#    -------------------- ------------------- 1/2 [zh-core-web-sm]
#    -------------------- ------------------- 1/2 [zh-core-web-sm]
#    ---------------------------------------- 2/2 [zh-core-web-sm]
#
# Successfully installed spacy-pkuseg-1.0.1 zh-core-web-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('zh_core_web_sm')
#
#
# Collecting hr-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download
MB 1.2 MB/s eta 0:00:03
#      ------------------------------- -------- 10.5/13.2 MB 1.2 MB/s eta 0:00:03
#      -------------------------------- ------- 10.7/13.2 MB 1.1 MB/s eta 0:00:03
#      -------------------------------- ------- 10.7/13.2 MB 1.1 MB/s eta 0:00:03
#      ---------------------------------- ----- 11.3/13.2 MB 1.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.5/13.2 MB 1.1 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.8/13.2 MB 1.1 MB/s eta 0:00:02
#      ------------------------------------- -- 12.3/13.2 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.6/13.2 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 12.8/13.2 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------- 13.2/13.2 MB 1.2 MB/s  0:00:11
# Installing collected packages: hr-core-news-sm
# Successfully installed hr-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('hr_core_news_sm')
#
#
# Collecting da-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/da_core_news_sm-3.8.0/da_core_news_sm-3.8.0-py3-none-any.whl (12.4 MB)
#      ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.4 MB 2.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/12.4 MB 1.7 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.3/12.4 MB 1.8 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.8/12.4 MB 2.0 MB/s eta 0:00:06
#      ------ --------------------------------- 2.1/12.4 MB 2.0 MB/s eta 0:00:06
#      -------- ------------------------------- 2.6/12.4 MB 2.0 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.1/12.4 MB 2.0 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.1/12.4 MB 2.0 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.1/12.4 MB 2.0 MB/s eta 0:00:05
#      ----------- ---------------------------- 3.4/12.4 MB 1.6 MB/s eta 0:00:06
#      ------------- -------------------------- 4.2/12.4 MB 1.7 MB/s eta 0:00:05
#      --------------- ------------------------ 4.7/12.4 MB 1.8 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.2/12.4 MB 1.8 MB/s eta 0:00:04
#      ------------------ --------------------- 5.8/12.4 MB 1.9 MB/s eta 0:00:04
#      -------------------- ------------------- 6.3/12.4 MB 2.0 MB/s eta 0:00:04
#      --------------------- ------------------ 6.6/12.4 MB 1.9 MB/s eta 0:00:04
#      ---------------------- ----------------- 6.8/12.4 MB 1.9 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.1/12.4 MB 1.8 MB/s eta 0:00:03
#      ------------------------ --------------- 7.6/12.4 MB 1.8 MB/s eta 0:00:03
#      --------------------------- ------------ 8.4/12.4 MB 1.9 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.2/12.4 MB 2.0 MB/s eta 0:00:02
#      -------------------------------- ------- 10.0/12.4 MB 2.1 MB/s eta 0:00:02
#      ---------------------------------- ----- 10.7/12.4 MB 2.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.3/12.4 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 11.8/12.4 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.4/12.4 MB 2.2 MB/s  0:00:05
# Installing collected packages: da-core-news-sm
# Successfully installed da-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('da_core_news_sm')
#
#
# Collecting nl-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nl_core_news_sm-3.8.0/nl_core_news_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.9 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/12.8 MB 2.0 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.8 MB 2.0 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.6/12.8 MB 1.8 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.8 MB 1.9 MB/s eta 0:00:06
#      ------- -------------------------------- 2.4/12.8 MB 2.0 MB/s eta 0:00:06
#      -------- ------------------------------- 2.9/12.8 MB 1.9 MB/s eta 0:00:06
#      ----------- ---------------------------- 3.7/12.8 MB 2.1 MB/s eta 0:00:05
#      ------------ --------------------------- 3.9/12.8 MB 2.0 MB/s eta 0:00:05
#      ------------- -------------------------- 4.5/12.8 MB 2.1 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.2/12.8 MB 2.2 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.5/12.8 MB 2.2 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.8/12.8 MB 2.1 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.8/12.8 MB 2.1 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.8/12.8 MB 2.1 MB/s eta 0:00:04
#      ------------------ --------------------- 6.0/12.8 MB 1.7 MB/s eta 0:00:04
#      -------------------- ------------------- 6.6/12.8 MB 1.8 MB/s eta 0:00:04
#      --------------------- ------------------ 6.8/12.8 MB 1.8 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.3/12.8 MB 1.8 MB/s eta 0:00:04
#      -------------------------- ------------- 8.4/12.8 MB 1.9 MB/s eta 0:00:03
#      ---------------------------- ----------- 9.2/12.8 MB 2.0 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 2.1 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 2.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 2.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.2 MB/s  0:00:05
# Installing collected packages: nl-core-news-sm
# Successfully installed nl-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('nl_core_news_sm')
#
#
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 2.6 MB/s eta 0:00:05
#      -- ------------------------------------- 0.8/12.8 MB 2.0 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.3/12.8 MB 2.1 MB/s eta 0:00:06
#      ------ --------------------------------- 2.1/12.8 MB 2.3 MB/s eta 0:00:05
#      ------- -------------------------------- 2.4/12.8 MB 2.2 MB/s eta 0:00:05
#      --------- ------------------------------ 3.1/12.8 MB 2.4 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.4/12.8 MB 2.3 MB/s eta 0:00:05
#      ----------- ---------------------------- 3.7/12.8 MB 2.1 MB/s eta 0:00:05
#      ------------ --------------------------- 3.9/12.8 MB 2.0 MB/s eta 0:00:05
#      ------------- -------------------------- 4.5/12.8 MB 2.1 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.2 MB/s eta 0:00:04
#      ------------------ --------------------- 5.8/12.8 MB 2.2 MB/s eta 0:00:04
#      ------------------- -------------------- 6.3/12.8 MB 2.3 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 2.2 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.3/12.8 MB 2.3 MB/s eta 0:00:03
#      ------------------------ --------------- 7.9/12.8 MB 2.3 MB/s eta 0:00:03
#      -------------------------- ------------- 8.4/12.8 MB 2.3 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/12.8 MB 2.3 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.8 MB 2.3 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.8 MB 2.4 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 2.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 2.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 2.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 2.2 MB/s  0:00:06
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
#
#
# Collecting fi-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fi_core_news_sm-3.8.0/fi_core_news_sm-3.8.0-py3-none-any.whl (14.3 MB)
#      ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#      - -------------------------------------- 0.5/14.3 MB 3.6 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/14.3 MB 4.7 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/14.3 MB 3.5 MB/s eta 0:00:04
#      ------- -------------------------------- 2.6/14.3 MB 3.5 MB/s eta 0:00:04
#      --------- ------------------------------ 3.4/14.3 MB 3.4 MB/s eta 0:00:04
#      ------------- -------------------------- 4.7/14.3 MB 3.9 MB/s eta 0:00:03
#      --------------- ------------------------ 5.5/14.3 MB 3.8 MB/s eta 0:00:03
#      ----------------- ---------------------- 6.3/14.3 MB 3.9 MB/s eta 0:00:03
#      ------------------- -------------------- 6.8/14.3 MB 3.9 MB/s eta 0:00:02
8 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.6 MB 4.9 MB/s eta 0:00:01
#      --------------------------------- ------ 10.5/12.6 MB 4.7 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.6 MB 4.7 MB/s eta 0:00:01
#      ---------------------------------------- 12.6/12.6 MB 4.7 MB/s  0:00:02
# Installing collected packages: el-core-news-sm
# Successfully installed el-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('el_core_news_sm')
#
#
# Collecting it-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.8.0/it_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ---------------------------------------- 0.0/13.0 MB ? eta -:--:--
#       --------------------------------------- 0.3/13.0 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/13.0 MB 3.8 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.8/13.0 MB 3.7 MB/s eta 0:00:04
#      -------- ------------------------------- 2.9/13.0 MB 4.0 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/13.0 MB 4.2 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/13.0 MB 4.3 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/13.0 MB 4.7 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/13.0 MB 4.8 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/13.0 MB 5.0 MB/s eta 0:00:01
#      ------------------------------ --------- 10.0/13.0 MB 5.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.7/13.0 MB 4.8 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/13.0 MB 4.9 MB/s eta 0:00:01
#      ---------------------------------------- 13.0/13.0 MB 4.9 MB/s  0:00:02
# Installing collected packages: it-core-news-sm
# Successfully installed it-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')
#
#
# Collecting ja-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ja_core_news_sm-3.8.0/ja_core_news_sm-3.8.0-py3-none-any.whl (12.1 MB)
#      ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.1 MB 4.6 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.1 MB 5.1 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.1/12.1 MB 4.7 MB/s eta 0:00:02
#      -------------- ------------------------- 4.5/12.1 MB 5.1 MB/s eta 0:00:02
#      ------------------- -------------------- 5.8/12.1 MB 5.2 MB/s eta 0:00:02
#      --------------------- ------------------ 6.6/12.1 MB 5.4 MB/s eta 0:00:02
#      ------------------------- -------------- 7.6/12.1 MB 4.9 MB/s eta 0:00:01
#      --------------------------- ------------ 8.4/12.1 MB 4.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.2/12.1 MB 4.7 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.5/12.1 MB 4.8 MB/s eta 0:00:01
#      ------------------------------------ --- 11.0/12.1 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.1/12.1 MB 4.6 MB/s  0:00:02
# Collecting sudachipy!=0.6.1,>=0.5.2 (from ja-core-news-sm==3.8.0)
#   Downloading SudachiPy-0.6.10-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting sudachidict-core>=20211220 (from ja-core-news-sm==3.8.0)
#   Downloading sudachidict_core-20260116-py3-none-any.whl.metadata (2.7 kB)
# Downloading sudachidict_core-20260116-py3-none-any.whl (72.2 MB)
#    ---------------------------------------- 0.0/72.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.2 MB ? eta -:--:--
#    ---------------------------------------- 0.8/72.2 MB 3.9 MB/s eta 0:00:19
#    - -------------------------------------- 1.8/72.2 MB 3.6 MB/s eta 0:00:20
#    - -------------------------------------- 2.9/72.2 MB 4.3 MB/s eta 0:00:17
#    -- ------------------------------------- 3.9/72.2 MB 4.2 MB/s eta 0:00:17
#    -- ------------------------------------- 5.2/72.2 MB 4.6 MB/s eta 0:00:15
#    --- ------------------------------------ 6.6/72.2 MB 4.8 MB/s eta 0:00:14
#    ---- -----------------------------------
0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: setuptools>=68.2.2 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0) (82.0.0)
# Downloading pymorphy3-2.0.6-py3-none-any.whl (53 kB)
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.4 MB 3.0 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.4 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.4 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.4 MB 3.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.9/8.4 MB 2.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.7/8.4 MB 2.6 MB/s eta 0:00:02
#    ------------------ --------------------- 3.9/8.4 MB 2.4 MB/s eta 0:00:02
#    ------------------ --------------------- 3.9/8.4 MB 2.4 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.4 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.4 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.7/8.4 MB 1.9 MB/s eta 0:00:03
#    --------------------------- ------------ 5.8/8.4 MB 1.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.0/8.4 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.3/8.4 MB 1.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.3/8.4 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 6.6/8.4 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 7.1/8.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.9/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.1/8.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 950.7 kB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 920.6 kB/s  0:00:09
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3, ru-core-news-sm
#
#    ---------------------------------------- 0/4 [pymorphy3-dicts-ru]
#    -------------------- ------------------- 2/4 [pymorphy3]
#    ------------------------------ --------- 3/4 [ru-core-news-sm]
#    ------------------------------ --------- 3/4 [ru-core-news-sm]
#    ---------------------------------------- 4/4 [ru-core-news-sm]
#
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.6 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
#
#
#
# âœ˜ No compatible package found for 'sk_core_news_sm' (spaCy v3.8.11)
#
#
#
# Collecting sl-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/sl_core_news_sm-3.8.0/sl_core_news_sm-3.8.0-py3-none-any.whl (13.6 MB)
#      ---------------------------------------- 0.0/13.6 MB ? eta -:--:--
#       --------------------------------------- 0.3/13.6 MB ? eta -:--:--
#      ---- ----------------------------------- 1.6/13.6 MB 5.2 MB/s eta 0:00:03
#      ------ --------------------------------- 2.4/13.6 MB 4.6 MB/s eta 0:00:03
#      --------- ------------------------------ 3.4/13.6 MB 4.8 MB/s eta 0:00:03
#      ------------- -------------------------- 4.5/13.6 MB 4.9 MB/s eta 0:00:02
#      --------------- ------------------------ 5.2/13.6 MB 4.5 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.5/13.6 MB 4.1 MB/s eta 0:00:02
#      ------------------- -------------------- 6.8/13.6 MB 4.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.9/13.6 MB 4.4 MB/s eta 0:00:02
#      ------------------------ --------------- 8.4/13.6 MB 4.2 MB/s eta 0:00:02
#      -------------------------- ------------- 8.9/13.6 MB 4.0 MB/s eta 0:00:02
#      -------------------------- ------------- 9.2/13.6 MB 3.8 MB/s eta 0:00:02
#      ----------------------------- ---------- 10.0/13.6 MB 3.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 10.2/13.6 MB 3.6 MB/s eta 0:00:01
#      ------------------------------ --------- 10.5/13.6 MB 3.5 MB/s eta 0:00:01
#      ------------------------------ --------- 10.5/13.6 MB 3.5 MB/s eta 0:00:01
#      ------------------------------ --------- 10.5/13.6 MB 3.5 MB/s eta 0:00:01
#      ------------------------------ --------- 10.5/13.6 MB 3.5 MB/s eta 0:00:01
#      ------------------------------ --------- 10.5/13.6 MB 3.5 MB/s eta 0:00:01
#      ------------------------------ --------- 10.5/13.6 MB 3.5 MB/s eta 0:00:01
#      -------------------------------- ------- 11.0/13.6 MB 2.5 MB/s eta 0:00:02
#      --------------------------------- ------ 11.3/13.6 MB 2.5 MB/s eta 0:00:01
#      --------------------------------- ------ 11.3/13.6 MB 2.5 MB/s eta 0:00:01
#      --------------------------------- ------ 11.3/13.6 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.8/13.6 MB 2.2 MB/s eta 0:00:01
#      ------------------------------------ --- 12.3/13.6 MB 2.3 MB/s eta 0:00:01
#      ------------------------------------ --- 12.6/13.6 MB 2.2 MB/s eta 0:00:01
#      ------------------------------------- -- 12.8/13.6 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  13.4/13.6 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------- 13.6/13.6 MB 2.1 MB/s  0:00:06
# Installing collected packages: sl-core-news-sm
# Successfully installed sl-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('sl_core_news_sm')
#
#
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.9 MB 3.8 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.3/12.9 MB 4.2 MB/s eta 0:00:03
#      -------- ------------------------------- 2.6/12.9 MB 4.0 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.9 MB 3.8 MB/s eta 0:00:03
#      ------------- -------------------------- 4.5/12.9 MB 4.1 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.5/12.9 MB 4.3 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.9 MB 4.4 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.9 MB 4.4 MB/s eta 0:00:02
#      -------------------------- ------------- 8.7/12.9 MB 4.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.9 MB 4.5 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.9 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.9 MB 4.4 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.9 MB 4.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 4.3 MB/s  0:00:03
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
#
#
# Collecting sv-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/sv_core_news_sm-3.8.0/sv_core_news_sm-3.8.0-py3-none-any.whl (12.7 MB)
#      ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#      ---- ----------------------------------- 1.3/12.7 MB 5.2 MB/s eta 0:00:03
#      -------- ------------------------------- 2.6/12.7 MB 5.5 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.7/12.7 MB 5.5 MB/s eta 0:00:02
#      --------------- ------------------------ 5.0/12.7 MB 5.4 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.7 MB 5.4 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.1/12.7 MB 5.4 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.7 MB 5.4 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.7 MB 5.2 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.7 MB 5.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.7 MB 5.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.7 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.7 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.7/12.7 MB 4.7 MB/s  0:00:02
# Installing collected packages: sv-core-news-sm
# Successfully installed sv-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('sv_core_news_sm')
#
#
# Collecting uk-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/uk_core_news_sm-3.8.0/uk_core_news_sm-3.8.0-py3-none-any.whl (14.9 MB)
#      ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/14.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/14.9 MB 3.1 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.6/14.9 MB 3.5 MB/s eta 0:00:04
#      ------ --------------------------------- 2.4/14.9 MB 3.6 MB/s eta 0:00:04
#      -------- ------------------------------- 3.1/14.9 MB 3.7 MB/s eta 0:00:04
#      --------- ------------------------------ 3.4/14.9 MB 3.3 MB/s eta 0:00:04
#      ----------- ---------------------------- 4.5/14.9 MB 3.4 MB/s eta 0:00:04
#      --------------- ------------------------ 5.8/14.9 MB 3.7 MB/s eta 0:00:03
#      ------------------ --------------------- 6.8/14.9 MB 4.0 MB/s eta 0:00:03
#      --------------------- ------------------ 8.1/14.9 MB 4.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 8.7/14.9 MB 4.1 MB/s eta 0:00:02
#      -------------------------- ------------- 10.0/14.9 MB 4.2 MB/s eta 0:00:02
#      ----------------------------- ---------- 11.0/14.9 MB 4.3 MB/s eta 0:00:01
#      ------------------------------ --------- 11.5/14.9 MB 4.2 MB/s eta 0:00:01
#      --------------------------------- ------ 12.3/14.9 MB 4.2 MB/s eta 0:00:01
#      --------------------------------- ------ 12.6/14.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 12.8/14.9 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------- ---- 13.1/14.9 MB 3.6 MB/s eta 0:00:01
#      ------------------------------------ --- 13.6/14.9 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------  14.7/14.9 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------- 14.9/14.9 MB 3.6 MB/s  0:00:04
# Requirement already satisfied: pymorphy3>=1.0.0 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from uk-core-news-sm==3.8.0) (2.0.6)
# Collecting pymorphy3-dicts-uk (from uk-core-news-sm==3.8.0)
#   Downloading pymorphy3_dicts_uk-2.4.1.1.1663094765-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: dawg2-python>=0.8.0 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from pymorphy3>=1.0.0->uk-core-news-sm==3.8.0) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from pymorphy3>=1.0.0->uk-core-news-sm==3.8.0) (2.4.417150.4580142)
# Requirement already satisfied: setuptools>=68.2.2 in D:\PycharmProjects\language-learning-agent\.venv\Lib\site-packages (from pymorphy3>=1.0.0->uk-core-news-sm==3.8.0) (82.0.0)
# Downloading pymorphy3_dicts_uk-2.4.1.1.1663094765-py2.py3-none-any.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.2 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.2 MB 3.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.2 MB 2.2 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.2 MB 2.8 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.2 MB 2.9 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 3.3 MB/s  0:00:02
# Installing collected packages: pymorphy3-dicts-uk, uk-core-news-sm
#
#    -------------------- ------------------- 1/2 [uk-core-news-sm]
#    -------------------- ------------------- 1/2 [uk-core-news-sm]
#    ---------------------------------------- 2/2 [uk-core-news-sm]
#
# Successfully installed pymorphy3-dicts-uk-2.4.1.1.1663094765 uk-core-news-sm-3.8.0
# âœ” Download and installation successful
# You can now load the package via spacy.load('uk_core_news_sm')

# %%
for language in spacy_models.keys():
    try:
        os.mkdir(f"../data/{language}")
        print(f"Directory {language} created")
    except FileExistsError:
        print(f"Directory {language} already exists")
# Out:
# Directory Catalan already exists
# Directory Chinese already exists
# Directory Croatian already exists
# Directory Danish already exists
# Directory Dutch already exists
# Directory English already exists
# Directory Finnish already exists
# Directory French already exists
# Directory German already exists
# Directory Greek already exists
# Directory Italian already exists
# Directory Japanese already exists
# Directory Korean already exists
# Directory Lithuanian already exists
# Directory Macedonian already exists
# Directory Norwegian already exists
# Directory Polish already exists
# Directory Portuguese already exists
# Directory Romanian already exists
# Directory Russian already exists
# Directory Slovenian already exists
# Directory Spanish already exists
# Directory Swedish already exists
# Directory Ukrainian already exists

# %%
def load_and_clean_word_list(language: str) -> pd.DataFrame:
    with open(f"../raw-word-list/{language}/{language}.txt", "r", encoding="utf-8") as f:
        word_list = f.read().split(",")

    word_df = pd.DataFrame({
        "word": word_list
    })

    word_df["word"] = word_df["word"].str.strip(punctuation)

    return word_df

# %%
load_and_clean_word_list("English")
# Out:
#               word
# 0         aardvark
# 1        aardvarks
# 2         aardwolf
# 3       aardwolves
# 4            Aaren
# ...            ...
# 466429      Zwolle
# 466430    Zworykin
# 466431          ZZ
# 466432         zZt
# 466433       ZZZ\n
#
# [466434 rows x 1 columns]

# %%
nlp = spacy.load(spacy_models["English"], disable=["parser", "ner", "textcat"])

# %%
def add_lemma(df: pd.DataFrame,
              nlp,
              batch_size: int = 1000) -> pd.DataFrame:
    docs = nlp.pipe(df["word"].tolist(), batch_size=batch_size)
    lemmas = [doc[0].lemma_ for doc in docs]
    df["lemma"] = pd.DataFrame(lemmas, index=df.index)
    return df

# %%
add_lemma(
    load_and_clean_word_list("English")[:100], nlp
)
# Out:
#           word     lemma
# 0     aardvark  aardvark
# 1    aardvarks  aardvark
# 2     aardwolf  aardwolf
# 3   aardwolves  aardwolf
# 4        Aaren     Aaren
# ..         ...       ...
# 95       Abama     Abama
# 96       abamp     abamp
# 97    abampere  abampere
# 98   abamperes  abampere
# 99      abamps    abamps
#
# [100 rows x 2 columns]

# %%
def add_word_frequencies(df: pd.DataFrame,
                         language: str) -> pd.DataFrame:
    language_group = spacy_models[language].split("_")[0]
    df["zipf_freq_lemma"] = [zipf_frequency(w, language_group) for w in df["lemma"]]
    return df

# %%
add_word_frequencies(
    add_lemma(
        load_and_clean_word_list("English")[:100], nlp
), "English")
# Out:
#           word     lemma  zipf_freq_lemma
# 0     aardvark  aardvark             2.39
# 1    aardvarks  aardvark             2.39
# 2     aardwolf  aardwolf             1.11
# 3   aardwolves  aardwolf             1.11
# 4        Aaren     Aaren             0.00
# ..         ...       ...              ...
# 95       Abama     Abama             0.00
# 96       abamp     abamp             0.00
# 97    abampere  abampere             0.00
# 98   abamperes  abampere             0.00
# 99      abamps    abamps             0.00
#
# [100 rows x 3 columns]

# %%
def clean_up_and_export(df: pd.DataFrame, language: str) -> None:
    df = (
        df.loc[df.groupby("lemma", sort=False)["zipf_freq_lemma"].idxmax()]
        .reset_index(drop=True)
    )

    df = df[(df["zipf_freq_lemma"] > 0)]

    df.loc[:, "word_difficulty"] = pd.cut(
        df["zipf_freq_lemma"],
        bins = [-float("inf"), 2.0, 4.0, float("inf")],
        labels = ["advanced", "intermediate", "beginner"],
        include_lowest = True,
        right = True
    )

    df = df.drop(columns=["word", "zipf_freq_lemma"])
    df = df.rename(columns = {
        "lemma": "word"
    })

    df.to_json(f"../data/{language}/word-list-cleaned.json", orient="index")

# %%
clean_up_and_export(
    add_word_frequencies(
        add_lemma(
            load_and_clean_word_list("English")[:100], nlp),
        "English"),
    "English")

# %%
def create_clean_word_list(language: str) -> None:
    nlp = spacy.load(spacy_models[language], disable=["parser", "ner", "textcat"])

    print("Load in dataset")
    lang_df = load_and_clean_word_list(language)

    print("Lemmatise words")
    lang_df = add_lemma(lang_df, nlp)

    print("Add the word frequencies")
    lang_df = add_word_frequencies(lang_df, language)

    print("Do the final clean ups and export to file")
    clean_up_and_export(lang_df, language)

    return None

# %%
create_clean_word_list("Spanish")
# Out:
# Load in dataset
# Lemmatise words
# Add the word frequencies
# Do the final clean ups and export to file

# %%
import json

language_raw = []
total_words_raw = []

for path, subdirs, files in os.walk("../raw-word-list"):
    for name in files:
        filename = (os.path.join(path, name))
        language_raw += [name.split(".")[0]]
        total_words_raw += [count_csv_elements_in_file(filename)]

raw_data = pd.DataFrame({
    "language": language_raw,
    "type": ["Raw"] * len(language_raw),
    "total_words_raw": total_words_raw,
})

# %%
language_clean = []
total_words_clean = []

for path, subdirs, files in os.walk("../data"):
    for name in files:
        filename = (os.path.join(path, name))
        language_clean += [path.split("/")[1]]
        with open(filename, "r", encoding="utf-8") as f:
            data = json.load(f)
            total_words_clean += [len(data.keys())]

clean_data = pd.DataFrame({
    "language": language_clean,
    "type": ["Clean"] * len(language_clean),
    "total_words_raw": total_words_clean,
})

pd.concat([raw_data, clean_data])
# Out:
#         language   type  total_words_raw
# 0        Catalan    Raw             3585
# 1        Chinese    Raw           406588
# 2       Croatian    Raw             3766
# 3         Danish    Raw          1800765
# 4          Dutch    Raw           173556
# 5        English    Raw           466434
# 6        Finnish    Raw            91672
# 7         French    Raw           336528
# 8         German    Raw          1707903
# 9          Greek    Raw            35279
# 10       Italian    Raw           661563
# 11      Japanese    Raw            44492
# 12        Korean    Raw           366504
# 13    Lithuanian    Raw            82627
# 14    Macedonian    Raw             3690
# 15     Norwegian    Raw           186966
# 16        Polish    Raw          4075605
# 17    Portuguese    Raw          1108873
# 18      Romanian    Raw           272616
# 19       Russian    Raw           171553
# 20        Slovak    Raw          1794373
# 21     Slovenian    Raw           344442
# 22       Spanish    Raw           636598
# 23       Swedish    Raw           403791
# 24     Ukrainian    Raw           126308
# 0   data\English  Clean               37
# 1   data\Spanish  Clean            68033
